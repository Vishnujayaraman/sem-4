# %%
import cv2
import numpy as np
from matplotlib import pyplot as py

# %%
a=cv2.imread("C:/Users/SN139/Downloads/car.jfif")

# %%
a
# Out:
# array([[[ 27,  95,  54],
#         [ 38, 106,  65],
#         [ 60, 126,  85],
#         ...,
#         [ 35,  76,  44],
#         [ 34,  75,  43],
#         [ 33,  74,  42]],
#
#        [[ 46, 112,  71],
#         [ 53, 119,  78],
#         [ 65, 128,  88],
#         ...,
#         [ 47,  88,  56],
#         [ 47,  88,  56],
#         [ 46,  87,  55]],
#
#        [[ 39, 100,  62],
#         [ 41, 102,  64],
#         [ 47, 107,  67],
#         ...,
#         [ 49,  90,  58],
#         [ 49,  90,  58],
#         [ 48,  89,  57]],
#
#        ...,
#
#        [[175, 200, 180],
#         [176, 201, 181],
#         [176, 201, 181],
#         ...,
#         [112, 172, 142],
#         [113, 171, 142],
#         [113, 171, 142]],
#
#        [[170, 198, 179],
#         [171, 199, 180],
#         [171, 199, 180],
#         ...,
#         [106, 164, 135],
#         [106, 164, 135],
#         [106, 164, 135]],
#
#        [[166, 196, 177],
#         [166, 196, 177],
#         [167, 197, 178],
# ...

# %%
a=cv2.imread("C:/Users/SN139/Downloads/car.jfif")
py.imshow(a),py.title("image")
py.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
